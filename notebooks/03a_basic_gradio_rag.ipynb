# %% [markdown]
# # 03a — Basic Gradio RAG
#
# This notebook outlines a basic Gradio interface for asking questions over an initialized vector database.

# %%
import gradio as gr

def answer_question(question):
    # Replace this placeholder with your vector DB retriever and LLM call.
    return f'Retrieved answer for: {question}'

demo = gr.Interface(
    fn=answer_question,
    inputs=gr.Textbox(label='Your Question'),
    outputs=gr.Textbox(label='AI Response'),
    title='Basic Gradio RAG'
)

# demo.launch()
